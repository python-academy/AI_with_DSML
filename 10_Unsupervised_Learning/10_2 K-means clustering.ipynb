# %% [markdown]
# ## Try 10.2.1: k-means clustering in Python.

# %% [markdown]
# **The Python code below clusters eruptions at Old Faithful based on the waiting time between eruptions and the duration of each eruption.**
#
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Change the number of clusters to k=3. Observe the changes in the clusters and within-cluster sums of squares (WCSS).**

# %%
# Import packages and functions
import os

# Set environment variables to avoid warnings
os.environ["LOKY_MAX_CPU_COUNT"] = "4"    # Set your number of physical cores
os.environ["OMP_NUM_THREADS"] = "2"        # Limit OpenMP threads
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# Load dataset
geyser = pd.read_csv('oldfaithful.csv')
geyser
# Out:
#      Eruption  Waiting
# 0       3.600       79
# 1       1.800       54
# 2       3.333       74
# 3       2.283       62
# 4       4.533       85
# ..        ...      ...
# 267     4.117       81
# 268     2.150       46
# 269     4.417       90
# 270     1.817       46
# 271     4.467       74
#
# [272 rows x 2 columns]

# %%
# Visual exploration
p = sns.scatterplot(data=geyser, x='Eruption', y='Waiting')
p.set_xlabel('Eruption time (min)', fontsize=14);
p.set_ylabel('Waiting time (min)', fontsize=14);

# %%
# Initialize a k-means model with k=2
kmModel = KMeans(n_clusters=2,n_init=10)

# Fit the model
kmModel = kmModel.fit(geyser)

# Save the cluster centroids
centroids = kmModel.cluster_centers_
centroids[1]
# Out:
# array([ 2.09433, 54.75   ])

# %%
# Save the cluster assignments
clusters = kmModel.fit_predict(geyser[['Eruption', 'Waiting']])

# View the clusters for the first five instances
clusters[0:5]
# Out:
# array([0, 1, 0, 1, 0])

# %%
# Plot clusters
p = sns.scatterplot(
    data=geyser, x='Eruption', y='Waiting', hue=clusters, style=clusters
)
p.set_xlabel('Eruption time (min)', fontsize=14);
p.set_ylabel('Waiting time (min)', fontsize=14);

# Add centroid for cluster 0
plt.scatter(x=centroids[0, 0], y=centroids[0, 1], c='black')

# Add centroid for cluster 1
plt.scatter(x=centroids[1, 0], y=centroids[1, 1], c='black', marker='X')

# %%
# Fit k-means clustering with k=1,...,5 and save WCSS for each
WCSS = []
k = [1, 2, 3, 4, 5]
for j in k:
    kmModel = KMeans(n_clusters=j)
    kmModel = kmModel.fit(geyser)
    WCSS.append(kmModel.inertia_)

# %%
# Plot the WCSS for each cluster
ax = plt.figure().gca()
plt.plot(k, WCSS, '*-')
plt.xlabel('Number of clusters (k)', fontsize=14);
plt.ylabel('Within-cluster sum of squares (WCSS)', fontsize=14);

# %% [markdown]
# ## challenge activity 10.2.2: K-means clustering using scikit-learn.

# %% [markdown]
# ## 1)
# **Researchers studying chemical properties of wines collected data on a sample of white wines in northern Portugal. One of the research goals was to cluster wines based on similar chemical properties.**
#
# * **Fit the k-means clustering model to cluster wines based on sulphates (sulphates) and citric acid (citric_acid).**
#
# **The code provided initializes the model with n_clusters=3 and random_state=rng and prints the cluster centers.**

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Read in the data
wines = pd.read_csv('whitewine.csv')

# Seed random number generator
rng = np.random.RandomState(26)

# Initialize k-means clustering model
kmeansModel = KMeans(n_clusters=3, random_state=rng)

# Your code goes here

print(kmeansModel.cluster_centers_)

# %% [markdown]
# ## 2)
# **Researchers studying chemical properties of wines collected data on a sample of white wines in northern Portugal. One of the research goals was to cluster wines based on similar chemical properties.**
#
# * **Initialize a k-means clustering model with n_clusters=4 and random_state=rng.**
# * **Fit the model to cluster wines based on volatile acidity (volatile_acidity) and alcohol concentration (alcohol).**
#
# **The code provided prints the cluster membership of the first five instances.**

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Read in the data
wines = pd.read_csv('whitewine.csv')

# Seed random number generator
rng = np.random.RandomState(36)

# Your code goes here

print(kmeansModel.labels_[0:5])

# %% [markdown]
# ## 3)
# **Researchers studying chemical properties of wines collected data on a sample of white wines in northern Portugal. One of the research goals was to cluster wines based on similar chemical properties.**
#
# * **Initialize a k-means clustering model with n_clusters=4 and random_state=rng.**
# * **Fit the model to cluster wines based on fixed acidity (fixed_acidity) and chlorides (chlorides).**
# * **Print the within cluster sums of squares for the fitted model.**

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Read in the data
wines = pd.read_csv('whitewine.csv')

# Seed random number generator
rng = np.random.RandomState(30)

# Your code goes here
